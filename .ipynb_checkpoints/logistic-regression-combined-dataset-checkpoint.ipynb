# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join(".", "datasets", "winequality-combined.csv"))
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
y = df["quality"]
target_names = ["negative", "positive"]

# %%
y
# Out:
# array([13, 13,  0,  4, 12,  3,  9,  9,  3, 13,  2,  8, 12,  5,  1, 13, 10,
#         8,  6,  5,  4, 11,  4, 12, 10, 12,  6,  2,  0,  0,  5, 13,  1,  9,
#         5,  4,  4,  2, 10, 11,  6,  8, 10, 11,  7,  3,  1, 10,  7,  4,  8,
#         3, 13,  0,  3,  2, 12,  5, 11,  9, 12,  6, 11,  3,  6,  4,  9, 10,
#         0,  1,  1,  2,  8, 11,  7, 10,  8,  2,  2,  3,  1,  1, 13,  5,  7,
#         6,  0,  9,  0, 12,  7,  0,  8,  7,  1,  9,  5,  7,  6, 11])

# %%
X
# Out:
# array([[ -5.05252259,   0.93608002],
#        [ -5.32026417,  -1.3280271 ],
#        [ -2.30033403,   7.054616  ],
#        [  2.93770235,   4.49020267],
#        [ -1.76245775,   5.85724433],
#        [ -8.75128069,   7.02451557],
#        [ -1.06802715,  -4.88976861],
#        [ -0.3977235 ,  -3.76263627],
#        [ -8.47693215,   8.86155948],
#        [ -5.43563385,   1.42025441],
#        [ -6.54836376,  -5.90456447],
#        [ -3.66466229,   0.84157684],
#        [ -0.36356505,   6.21730518],
#        [ -9.58319666,   9.16360991],
#        [  3.16135685,   1.25332548],
#        [ -6.77934957,   0.04787016],
#        [  1.97240106,  -4.48995362],
#        [ -4.59517986,   0.72738233],
#        [  6.45649185,  -5.45167044],
#        [ -9.74959583,   9.8022479 ],
#        [  1.32024714,   3.83378941],
#        [ -4.38056981,  -1.95876264],
#        [  1.21380663,   3.65969451],
#        [  0.20445093,   6.75732128],
#        [  2.51374869,  -6.38293954],
#        [ -0.8203916 ,   4.56054893],
#        [  8.05164713,  -7.15506885],
#        [ -7.98596217,  -8.07631622],
#        [ -3.6601912 ,   9.38998415],
#        [ -3.11090424,  10.86656431],
#        [ -9.33075972,   9.32375113],
#        [ -3.69186579,  -1.58257642],
#        [  4.52423055,   1.67206599],
#        [ -0.53903947,  -2.27862421],
#        [-11.50708133,   9.37168317],
#        [  1.49254003,   4.67471899],
#        [  1.63019208,   2.69793661],
#        [ -6.06710137,  -5.52386956],
#        [  2.25005979,  -5.75658871],
#        [ -5.00390075,  -4.18761036],
#        [  7.23570991,  -3.56276216],
#        [ -3.65527235,   1.2769515 ],
#        [  1.99166978,  -7.96385895],
#        [ -5.22799953,  -2.19029072],
#        [ -7.14675395,  -6.65397132],
#        [ -8.74656698,   5.335954  ],
#        [  4.96396281,   1.5880874 ],
#        [  1.34754346,  -8.02593307],
#        [ -7.28292489,  -4.7819754 ],
#        [  2.31842051,   4.42250683],
#        [ -3.68769521,   1.80227139],
#        [-11.45807286,   8.14542542],
#        [ -6.3217936 ,   1.04365799],
#        [ -3.10983631,   8.72259238],
#        [ -9.05799964,   7.68063549],
#        [ -6.95163731,  -5.8765767 ],
#        [ -0.52081296,   6.26430375],
#        [-11.00368086,   8.97755172],
#        [ -3.6838694 ,  -2.74559205],
#        [  0.50467488,  -3.70158428],
#        [ -2.25626968,   4.76569419],
#        [  6.70908303,  -3.28997567],
#        [ -4.60362198,  -1.81636434],
#        [ -8.8741538 ,   8.88816657],
#        [  7.79167563,  -5.00128475],
#        [  2.11937778,   5.13009655],
#        [ -2.3357813 ,  -3.38833259],
#        [  2.15995619,  -6.86897081],
#        [ -3.05358035,   9.12520872],
#        [  4.17924007,   3.03029191],
#        [  5.37834542,   2.14453797],
#        [ -6.51799117,  -7.52522935],
#        [ -5.15210585,  -0.82532798],
#        [ -3.94301329,  -3.91850191],
#        [ -5.54998344,  -7.56277412],
#        [  2.86272524,  -8.06728034],
#        [ -3.39321358,   0.79211331],
#        [ -7.71884471,  -7.18932197],
#        [ -7.35880143,  -7.06576857],
#        [ -7.36043371,   6.8052527 ],
#        [  4.98349713,   0.21012953],
#        [  5.67087836,   2.9044498 ],
#        [ -6.4918879 ,   0.36656291],
#        [ -9.93102463,   8.59591977],
#        [ -7.42580437,  -5.85831737],
#        [  6.61414105,  -6.92189582],
#        [ -1.68665271,   7.79344248],
#        [ -2.55240312,  -3.51886359],
#        [ -2.52269485,   7.9565752 ],
#        [ -0.36355263,   9.55625072],
#        [ -6.26384929,  -6.83538546],
#        [ -3.83738367,   9.21114736],
#        [ -5.52263838,   0.67976249],
#        [ -7.91416409,  -6.26334683],
#        [  3.96295684,   2.58484597],
#        [ -0.20250405,  -4.99609951],
#        [ -7.70212421,   9.57277486],
#        [ -7.35403698,  -6.89820753],
#        [  7.43988476,  -6.66260524],
#        [ -3.9839261 ,  -2.28744575]])

# %%
X = df.drop("quality", axis=1)
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol
# 0      8.8
# 1      9.5
# 2     10.1
# 3      9.9
# 4      9.9

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 6492                 32.0                  44.0  0.99490  3.45       0.58
# 6493                 39.0                  51.0  0.99512  3.52       0.76
# 6494                 29.0                  40.0  0.99574  3.42       0.75
# 6495                 32.0                  44.0  0.99547  3.57       0.71
# 6496                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         8.8
# 1         9.5
# 2        10.1
# 3         9.9
# 4         9.9
# ...       ...
# 6492     10.5
# 6493     11.2
# 6494     11.0
# 6495     10.2
# 6496     11.0
#
# [6497 rows x 11 columns]

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(centers=14, random_state=42)

print(f"Labels: {y[:10]}")
print(f"Data: {X[:10]}")
# Out:
# Labels: [13 13  0  4 12  3  9  9  3 13]
# Data: [[-5.05252259  0.93608002]
#  [-5.32026417 -1.3280271 ]
#  [-2.30033403  7.054616  ]
#  [ 2.93770235  4.49020267]
#  [-1.76245775  5.85724433]
#  [-8.75128069  7.02451557]
#  [-1.06802715 -4.88976861]
#  [-0.3977235  -3.76263627]
#  [-8.47693215  8.86155948]
#  [-5.43563385  1.42025441]]

# %%
# Visualizing both classes
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# C:\Users\Rober\anaconda\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.9066666666666666
# Testing Data Score: 0.68

# %%
# Generate a new data point (the red circle)
import numpy as np
new_data = np.array([[-2, 6]])
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.scatter(new_data[0, 0], new_data[0, 1], c="r", marker="o", s=100)

# %%
# Predict the class (purple or yellow) of the new data point
predictions = classifier.predict(new_data)
print("Classes are either 0 (purple) or 1 (yellow)")
print(f"The new point was classified as: {predictions}")
# Out:
# Classes are either 0 (purple) or 1 (yellow)
# The new point was classified as: [12]

# %%
predictions = classifier.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#     Prediction  Actual
# 0            1       1
# 1            2       7
# 2            9       9
# 3            1       1
# 4            2       7
# 5            8       8
# 6            4       4
# 7           13      13
# 8            1       1
# 9            4       4
# 10          13       8
# 11          11      11
# 12          12      12
# 13          13      13
# 14           5       3
# 15           1       1
# 16          11      13
# 17           2       7
# 18           2       2
# 19           2       2
# 20          12       0
# 21          11      11
# 22           2       7
# 23          11      11
# 24           5       5
